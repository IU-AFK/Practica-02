# %%
text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!"""

total_lines = text.split("\n")
print(f"Cantidad total de lineas: {len(total_lines)}")

total_words = []

for l in total_lines:
    total_words.extend(l.split(" "))
    
print(f"Cantidad total de palabras: {len(total_words)}")

prom = int(len(total_words)/len(total_lines))

print(f"El promedio de palabras por linea es: {prom}")

for l in total_lines:
    cant = []
    cant.extend(l.split(" "))
    if len(cant) > prom:
        print(f"Linea por encima del promedio: {l} ({len(cant)})")
# Out:
# Cantidad total de lineas: 19
# Cantidad total de palabras: 137
# El promedio de palabras por linea es: 7
# Linea por encima del promedio: Special cases aren't special enough to break the rules. (9)
# Linea por encima del promedio: In the face of ambiguity, refuse the temptation to guess. (10)
# Linea por encima del promedio: There should be one-- and preferably only one --obvious way to do it. (13)
# Linea por encima del promedio: Although that way may not be obvious at first unless you're Dutch. (12)
# Linea por encima del promedio: Although never is often better than *right* now. (8)
# Linea por encima del promedio: If the implementation is hard to explain, it's a bad idea. (11)
# Linea por encima del promedio: If the implementation is easy to explain, it may be a good idea. (13)
# Linea por encima del promedio: Namespaces are one honking great idea -- let's do more of those! (12)
